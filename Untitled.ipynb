# %%
import yfinance as yf
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
from scipy.stats import zscore

# %%
ticker = "SPY"
etf = yf.Ticker(ticker)
asset = etf.ticker
etf_data = etf.history(period="5y")
data = yf.download(asset, period="5y")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
momentum_factors = pd.DataFrame()
etf_returns = etf_data.pct_change()
momentum_factors = (etf_returns + 1).rolling(12).apply(np.prod, raw=True)-1

# %%
momentum_factors
# Out:
#                 Open      High       Low     Close    Volume  Dividends  \
# Date
# 2018-05-21       NaN       NaN       NaN       NaN       NaN        NaN
# 2018-05-22       NaN       NaN       NaN       NaN       NaN        NaN
# 2018-05-23       NaN       NaN       NaN       NaN       NaN        NaN
# 2018-05-24       NaN       NaN       NaN       NaN       NaN        NaN
# 2018-05-25       NaN       NaN       NaN       NaN       NaN        NaN
# ...              ...       ...       ...       ...       ...        ...
# 2023-05-15  0.012826  0.001793  0.008580  0.001455 -0.416045        NaN
# 2023-05-16  0.000899 -0.007501 -0.002892 -0.013656 -0.354059        NaN
# 2023-05-17 -0.007510 -0.004214 -0.011149 -0.000674  0.405083        NaN
# 2023-05-18  0.000313  0.011692  0.016797  0.020422 -0.065590        NaN
# 2023-05-19  0.021417  0.016551  0.023494  0.025979  0.132718        NaN
#
#             Stock Splits
# Date
# 2018-05-21           NaN
# 2018-05-22           NaN
# 2018-05-23           NaN
# 2018-05-24           NaN
# 2018-05-25           NaN
# ...                  ...
# 2023-05-15           NaN
# 2023-05-16           NaN
# 2023-05-17           NaN
# 2023-05-18           NaN
# 2023-05-19           NaN
#
# [1259 rows x 7 columns]

# %%
z_scores = (momentum_factors - momentum_factors.mean()) / momentum_factors.std()
z_scores
# Out:
#                 Open      High       Low     Close    Volume  Dividends  \
# Date
# 2018-05-21       NaN       NaN       NaN       NaN       NaN        NaN
# 2018-05-22       NaN       NaN       NaN       NaN       NaN        NaN
# 2018-05-23       NaN       NaN       NaN       NaN       NaN        NaN
# 2018-05-24       NaN       NaN       NaN       NaN       NaN        NaN
# 2018-05-25       NaN       NaN       NaN       NaN       NaN        NaN
# ...              ...       ...       ...       ...       ...        ...
# 2023-05-15  0.170533 -0.098016  0.062550 -0.101600 -0.825218        NaN
# 2023-05-16 -0.115330 -0.338474 -0.196505 -0.461912 -0.731450        NaN
# 2023-05-17 -0.316878 -0.253441 -0.382946 -0.152359  0.416941        NaN
# 2023-05-18 -0.129369  0.158085  0.248070  0.350649 -0.295069        NaN
# 2023-05-19  0.376457  0.283804  0.399288  0.483165  0.004921        NaN
#
#             Stock Splits
# Date
# 2018-05-21           NaN
# 2018-05-22           NaN
# 2018-05-23           NaN
# 2018-05-24           NaN
# 2018-05-25           NaN
# ...                  ...
# 2023-05-15           NaN
# 2023-05-16           NaN
# 2023-05-17           NaN
# 2023-05-18           NaN
# 2023-05-19           NaN
#
# [1259 rows x 7 columns]

# %%
long_basket = z_scores.mean(axis=1).nlargest(15).index
long_basket
# Out:
# DatetimeIndex(['2020-04-08', '2020-04-09', '2020-04-07', '2020-04-20',
#                '2020-04-22', '2020-04-13', '2020-04-21', '2020-11-16',
#                '2020-04-17', '2020-11-17', '2022-03-30', '2020-06-05',
#                '2020-06-10', '2020-06-03', '2020-04-14'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
short_basket = z_scores.mean(axis=1).nsmallest(15).index.tolist()
short_basket
# Out:
# [Timestamp('2020-03-23 00:00:00'),
#  Timestamp('2020-03-20 00:00:00'),
#  Timestamp('2020-03-19 00:00:00'),
#  Timestamp('2020-03-18 00:00:00'),
#  Timestamp('2020-03-16 00:00:00'),
#  Timestamp('2020-03-12 00:00:00'),
#  Timestamp('2020-03-24 00:00:00'),
#  Timestamp('2020-03-17 00:00:00'),
#  Timestamp('2020-03-13 00:00:00'),
#  Timestamp('2020-03-11 00:00:00'),
#  Timestamp('2020-03-10 00:00:00'),
#  Timestamp('2020-03-09 00:00:00'),
#  Timestamp('2018-12-24 00:00:00'),
#  Timestamp('2022-06-17 00:00:00'),
#  Timestamp('2022-06-16 00:00:00')]

# %%
start_date = etf_data.index[-1] - pd.DateOffset(years=5)
backtest_data = etf_data.loc[start_date:]

# %%
backtest_data
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2018-05-21  250.706579  251.597336  250.302522  251.037155   58025900
# 2018-05-22  251.578982  251.845298  249.999495  250.339264   52966400
# 2018-05-23  249.016906  251.055545  248.851590  251.027969   64694200
# 2018-05-24  250.614776  250.899449  248.658781  250.513748   76043800
# 2018-05-25  249.916870  250.568859  249.393429  249.916870   56374800
# ...                ...         ...         ...         ...        ...
# 2023-05-15  412.220001  413.429993  410.230011  413.010010   54289400
# 2023-05-16  411.859985  412.820007  410.239990  410.250000   57705500
# 2023-05-17  412.350006  415.859985  410.640015  415.230011   87287000
# 2023-05-18  414.899994  419.670013  414.670013  419.230011   97177200
# 2023-05-19  420.170013  420.720001  417.350006  418.619995  103679700
#
#             Dividends  Stock Splits
# Date
# 2018-05-21        0.0             0
# 2018-05-22        0.0             0
# 2018-05-23        0.0             0
# 2018-05-24        0.0             0
# 2018-05-25        0.0             0
# ...               ...           ...
# 2023-05-15        0.0             0
# 2023-05-16        0.0             0
# 2023-05-17        0.0             0
# 2023-05-18        0.0             0
# 2023-05-19        0.0             0
#
# [1259 rows x 7 columns]

# %%
plt.figure(figsize=(12, 8))

# %%
 def get_portfolio_basket(self):
        return pd.concat([self.get_smallest_basket(),self.get_largest_basket()]).sort_values('Monthly Z-Factor Score', ascending=False)

# %%
 def get_monthly_info(self,basket):
        port_monthly_mean = self.monthly_mean[basket.index.tolist()].copy()
        port_monthly_mean['Portfolio Monthly Return'] = port_monthly_mean[basket.index.tolist()].sum(axis=1)
        port_monthly_mean['Portfolio Precent Change'] = port_monthly_mean[basket.index.tolist()].pct_change().sum(axis=1)
        port_monthly_mean['Cumulative Monthly Return'] = port_monthly_mean['Portfolio Monthly Return'].cumsum()
        port_monthly_mean['Cumulative Portfolio Percent Change'] = port_monthly_mean['Portfolio Precent Change'].cumsum()

# %%
def get_etf_monthly_mean(self):
        etf_df = self.etf_assets_data_df.groupby(pd.Grouper(freq='M')).mean()
        etf_df['Portfolio Monthly Return'] = etf_df[self.etf_assets_data_df.columns.tolist()].sum(axis=1)
        etf_df['Portfolio Precent Change'] = etf_df[self.etf_assets_data_df.columns.tolist()].pct_change().sum(axis=1)
        etf_df['Cumulative Monthly Return'] = etf_df['Portfolio Monthly Return'].cumsum()
        etf_df['Cumulative Portfolio Percent Change'] = etf_df['Portfolio Precent Change'].cumsum()

# %%
 def plot_information(self, plot_vars, ylabel=None, xlabel=None, title=None, figsize=(6,15), xlim=(0,100000)):
        import matplotlib.pyplot as plt
        f, ax = plt.subplots(figsize=figsize)

# %%
plt.plot()
# Out:
# []
